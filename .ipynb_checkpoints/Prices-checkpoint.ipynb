# %%
import numpy as np
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
train = pd.read_csv('train.csv')
test = pd.read_csv('test.csv')

# %%
train.nunique()
# Out:
# Id               1460
# MSSubClass         15
# MSZoning            5
# LotFrontage       110
# LotArea          1073
#                  ...
# MoSold             12
# YrSold              5
# SaleType            9
# SaleCondition       6
# SalePrice         663
# Length: 81, dtype: int64

# %%
test.nunique()
# Out:
# Id               1459
# MSSubClass         16
# MSZoning            5
# LotFrontage       115
# LotArea          1106
#                  ...
# MiscVal            26
# MoSold             12
# YrSold              5
# SaleType            9
# SaleCondition       6
# Length: 80, dtype: int64

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1459 entries, 0 to 1458
# Data columns (total 80 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1459 non-null   int64
#  1   MSSubClass     1459 non-null   int64
#  2   MSZoning       1455 non-null   object
#  3   LotFrontage    1232 non-null   float64
#  4   LotArea        1459 non-null   int64
#  5   Street         1459 non-null   object
#  6   Alley          107 non-null    object
#  7   LotShape       1459 non-null   object
#  8   LandContour    1459 non-null   object
#  9   Utilities      1457 non-null   object
#  10  LotConfig      1459 non-null   object
#  11  LandSlope      1459 non-null   object
#  12  Neighborhood   1459 non-null   object
#  13  Condition1     1459 non-null   object
#  14  Condition2     1459 non-null   object
#  15  BldgType       1459 non-null   object
#  16  HouseStyle     1459 non-null   object
# ...

# %%
corrs=train.drop('SalePrice',axis=1).corrwith(train['SalePrice']).sort_values(ascending=False)

# %%
fig,axes=plt.subplots(1,1,figsize=(15,9))
fig.patch.set_facecolor('#000000')
axes.patch.set_facecolor('#000000')
axes.tick_params(axis='x', colors='white')
axes.tick_params(axis='y', colors='white')
axes.yaxis.set_ticks_position('none')
axes.yaxis.label.set_color('white')
axes.grid(color='#354555', linewidth=.7)
axes.axhline(corrs.mean(), ls='--',color='white')
axes.text(25.5,.31, "Average={:.3f}".format(corrs.mean()),color='white',size=12,fontweight='bold')
sns.barplot(y=corrs,x=corrs.index,palette='Spectral')
plt.title('Correlation of Sale Price to other Features',size=25,fontweight='bold',color='white',y=1.03)
plt.xticks(fontsize=13)
plt.yticks(fontsize=13)
plt.xticks(rotation=90);

# %%
from scipy.stats import norm
plt.figure(figsize=(15,9))
mu, sigma = norm.fit(train['SalePrice'])
sns.distplot(train['SalePrice'],fit=norm,color='b',rug=True,kde_kws={'shade':True,'color':'b','alpha':.2})
plt.legend(['$\mu=$ {:.3f} and $\sigma=$ {:.3f}'.format(mu, sigma)],fontsize=14)
plt.title('Distribution of Sale Price',size=25,fontweight='bold');

# %%
sns.heatmap(train.isnull(),cmap = 'viridis',cbar=False,yticklabels=False)

# %%
sns.heatmap(test.isnull(),cmap='viridis',cbar=False,yticklabels=False)

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %%
train = train.drop(['PoolQC','Fence','MiscFeature','Alley'],axis=1)

# %%
train.shape
# Out:
# (1460, 77)

# %%
train = train.drop('GarageYrBlt',axis=1)

# %%
train['LotFrontage'] = train['LotFrontage'].fillna(train['LotFrontage'].mean())
train['MasVnrArea'] = train['MasVnrArea'].fillna(train['MasVnrArea'].mean())

# %%
train['MasVnrType'] = train['MasVnrType'].fillna(train['MasVnrType'].mode()[0])
train['BsmtQual'] = train['BsmtQual'].fillna(train['BsmtQual'].mode()[0])
train['BsmtCond'] = train['BsmtCond'].fillna(train['BsmtCond'].mode()[0])
train['BsmtExposure'] = train['BsmtExposure'].fillna(train['BsmtExposure'].mode()[0])
train['BsmtFinType1'] = train['BsmtFinType1'].fillna(train['BsmtFinType1'].mode()[0])
train['BsmtFinType2'] = train['BsmtFinType2'].fillna(train['BsmtFinType2'].mode()[0])
train['Electrical'] = train['Electrical'].fillna(train['Electrical'].mode()[0])
train['FireplaceQu'] = train['FireplaceQu'].fillna(train['FireplaceQu'].mode()[0])
train['GarageType'] = train['GarageType'].fillna(train['GarageType'].mode()[0])
train['GarageFinish'] = train['GarageFinish'].fillna(train['GarageFinish'].mode()[0])
train['GarageQual'] = train['GarageQual'].fillna(train['GarageQual'].mode()[0])
train['GarageCond'] = train['GarageCond'].fillna(train['GarageCond'].mode()[0])
train['MasVnrType'] = train['MasVnrType'].fillna(train['MasVnrType'].mode()[0])

# %%
sns.heatmap(train.isnull(),cbar=False,cmap='viridis',yticklabels=False)

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1459 entries, 0 to 1458
# Data columns (total 80 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1459 non-null   int64
#  1   MSSubClass     1459 non-null   int64
#  2   MSZoning       1455 non-null   object
#  3   LotFrontage    1232 non-null   float64
#  4   LotArea        1459 non-null   int64
#  5   Street         1459 non-null   object
#  6   Alley          107 non-null    object
#  7   LotShape       1459 non-null   object
#  8   LandContour    1459 non-null   object
#  9   Utilities      1457 non-null   object
#  10  LotConfig      1459 non-null   object
#  11  LandSlope      1459 non-null   object
#  12  Neighborhood   1459 non-null   object
#  13  Condition1     1459 non-null   object
#  14  Condition2     1459 non-null   object
#  15  BldgType       1459 non-null   object
#  16  HouseStyle     1459 non-null   object
# ...

# %%
test = test.drop(['PoolQC','Fence','MiscFeature','Alley','GarageYrBlt'],axis=1)

# %%
test.shape
# Out:
# (1459, 75)

# %%
test['LotFrontage'] = test['LotFrontage'].fillna(test['LotFrontage'].mean())
test['MasVnrArea'] = test['MasVnrArea'].fillna(test['MasVnrArea'].mean())
test['BsmtFinSF1'] = test['BsmtFinSF1'].fillna(test['BsmtFinSF1'].mean())
test['BsmtFinSF2'] = test['BsmtFinSF2'].fillna(test['BsmtFinSF2'].mean())
test['BsmtUnfSF'] = test['BsmtUnfSF'].fillna(test['BsmtUnfSF'].mean())
test['TotalBsmtSF'] = test['TotalBsmtSF'].fillna(test['TotalBsmtSF'].mean())
test['BsmtFullBath'] = test['BsmtFullBath'].fillna(test['BsmtFullBath'].mean())
test['BsmtHalfBath'] = test['BsmtHalfBath'].fillna(test['BsmtHalfBath'].mean())
test['GarageCars'] = test['GarageCars'].fillna(test['GarageCars'].mean())
test['GarageArea'] = test['GarageArea'].fillna(test['GarageArea'].mean())
test['GarageArea'] = test['TotalBsmtSF'].fillna(test['TotalBsmtSF'].mean())

# %%
test['MSZoning'] = test['MSZoning'].fillna(test['MSZoning'].mode()[0])
test['Utilities'] = test['Utilities'].fillna(test['Utilities'].mode()[0])
test['Exterior1st'] = test['Exterior1st'].fillna(test['Exterior1st'].mode()[0])
test['Exterior2nd'] = test['Exterior2nd'].fillna(test['Exterior2nd'].mode()[0])
test['MasVnrType'] = test['MasVnrType'].fillna(test['MasVnrType'].mode()[0])
test['BsmtQual'] = test['BsmtQual'].fillna(test['BsmtQual'].mode()[0])
test['BsmtCond'] = test['BsmtCond'].fillna(test['BsmtCond'].mode()[0])
test['BsmtExposure'] = test['BsmtExposure'].fillna(test['BsmtExposure'].mode()[0])
test['BsmtFinType1'] = test['BsmtFinType1'].fillna(test['BsmtFinType1'].mode()[0])
test['BsmtFinType2'] = test['BsmtFinType2'].fillna(test['BsmtFinType2'].mode()[0])
test['KitchenQual'] = test['KitchenQual'].fillna(test['KitchenQual'].mode()[0])
test['Functional'] = test['KitchenQual'].fillna(test['KitchenQual'].mode()[0])
test['FireplaceQu'] = test['FireplaceQu'].fillna(test['FireplaceQu'].mode()[0])
test['GarageType'] = test['GarageType'].fillna(test['GarageType'].mode()[0])
test['GarageFinish'] = test['GarageFinish'].fillna(test['GarageFinish'].mode()[0])
test['GarageQual'] = test['GarageQual'].fillna(test['GarageQual'].mode()[0])
test['GarageCond'] = test['GarageCond'].fillna(test['GarageCond'].mode()[0])
test['SaleType'] = test['SaleType'].fillna(test['SaleType'].mode()[0])

# %%
sns.heatmap(test.isnull(),yticklabels=False,cbar=False,cmap='viridis')

# %%
columns=['MSZoning','Street','LotShape','LandContour','Utilities','LotConfig','LandSlope','Neighborhood',
         'Condition2','BldgType','Condition1','HouseStyle','SaleType',
        'SaleCondition','ExterCond',
         'ExterQual','Foundation','BsmtQual','BsmtCond','BsmtExposure','BsmtFinType1','BsmtFinType2',
        'RoofStyle','RoofMatl','Exterior1st','Exterior2nd','MasVnrType','Heating','HeatingQC',
         'CentralAir',
         'Electrical','KitchenQual','Functional',
         'FireplaceQu','GarageType','GarageFinish','GarageQual','GarageCond','PavedDrive']

# %%
print(train.shape)
print(test.shape)
# Out:
# (1460, 76)
# (1459, 75)

# %%
len(columns)
# Out:
# 39

# %%
def category_onehot_multcols(multcolumns):
    df_final=final_df
    i=0
    for fields in multcolumns:
        
        print(fields)
        df1=pd.get_dummies(final_df[fields],drop_first=True)
        
        final_df.drop([fields],axis=1,inplace=True)
        if i==0:
            df_final=df1.copy()
        else:
            
            df_final=pd.concat([df_final,df1],axis=1)
        i=i+1
       
        
    df_final=pd.concat([final_df,df_final],axis=1)
        
    return df_final

# %%
main_df=train.copy()

# %%
final_df=pd.concat([train,test],axis=0)

# %%
final_df['SalePrice']
# Out:
# 0       208500.0
# 1       181500.0
# 2       223500.0
# 3       140000.0
# 4       250000.0
#           ...
# 1454         NaN
# 1455         NaN
# 1456         NaN
# 1457         NaN
# 1458         NaN
# Name: SalePrice, Length: 2919, dtype: float64

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 76 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1460 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   LotShape       1460 non-null   object
#  7   LandContour    1460 non-null   object
#  8   Utilities      1460 non-null   object
#  9   LotConfig      1460 non-null   object
#  10  LandSlope      1460 non-null   object
#  11  Neighborhood   1460 non-null   object
#  12  Condition1     1460 non-null   object
#  13  Condition2     1460 non-null   object
#  14  BldgType       1460 non-null   object
#  15  HouseStyle     1460 non-null   object
#  16  OverallQual    1460 non-null   int64
# ...

# %%
final_df.shape
# Out:
# (2919, 76)

# %%
final_df = final_df.drop('Id',axis=1)

# %%
final_df=category_onehot_multcols(columns)
# Out:
# MSZoning
# Street
# LotShape
# LandContour
# Utilities
# LotConfig
# LandSlope
# Neighborhood
# Condition2
# BldgType
# Condition1
# HouseStyle
# SaleType
# SaleCondition
# ExterCond
# ExterQual
# Foundation
# BsmtQual
# BsmtCond
# BsmtExposure
# BsmtFinType1
# BsmtFinType2
# RoofStyle
# RoofMatl
# Exterior1st
# Exterior2nd
# MasVnrType
# Heating
# HeatingQC
# CentralAir
# Electrical
# KitchenQual
# Functional
# FireplaceQu
# GarageType
# GarageFinish
# GarageQual
# GarageCond
# PavedDrive

# %%
final_df.shape
# Out:
# (2919, 240)

# %%
final_df =final_df.loc[:,~final_df.columns.duplicated()]

# %%
final_df.shape
# Out:
# (2919, 177)

# %%
train_df=final_df.iloc[:1460,:]
test_df=final_df.iloc[1460:,:]

# %%
print(train_df.shape)
print(test_df.shape)
# Out:
# (1460, 177)
# (1459, 177)

# %%
test_df.drop(['SalePrice'],axis=1,inplace=True)
# Out:
# C:\Users\Abhinav\anaconda3\lib\site-packages\pandas\core\frame.py:3997: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
test_df.shape
# Out:
# (1459, 176)

# %%
from sklearn.linear_model import Lasso,ElasticNet,Ridge,LinearRegression
from sklearn.neighbors import KNeighborsRegressor
from sklearn.svm import SVR
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor,GradientBoostingRegressor
from sklearn.gaussian_process import GaussianProcessRegressor
from xgboost import XGBRegressor as xgb
from sklearn.model_selection import cross_val_score,train_test_split,KFold,GridSearchCV
from sklearn.pipeline import make_pipeline ,Pipeline
from sklearn.preprocessing import RobustScaler

# %%
# %%time
params={'model__random_state':[42],
        'model__alpha':[.0001,.001,.005],
        'model__selection' : ('cyclic', 'random'),
        'model__normalize':(True,False),
        'model__max_iter':[13,14,15],
       'model__tol':[1e-06,.00001,1e-04],
       'model__positive':(True,False),
       'model__warm_start':(True,False)}


pipeline = Pipeline([('scaler', RobustScaler()),('model',Lasso())])

grid = GridSearchCV(pipeline, cv=5, param_grid=params,scoring='neg_mean_squared_error')
grid.fit(X_train, y_train)
grid.best_params_
# Out:
# C:\Users\Abhinav\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 279601312354.1669, tolerance: 4741977.950469258
#   positive)
# C:\Users\Abhinav\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 215391261092.84344, tolerance: 4839855.126952247
#   positive)
# C:\Users\Abhinav\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 295644342292.10333, tolerance: 4842038.06080445
#   positive)
# ...

# %%
# %%time
params={'model__random_state':[42],
        'model__alpha':[.0095,.01,.015],
        'model__l1_ratio' : [.045,.05,.55],
        'model__normalize':(True,False),
        'model__max_iter':[100,110,120],
       'model__tol':[1e-07,1e-06],
       'model__positive':(True,False)}


pipeline = Pipeline([('scaler', RobustScaler()),('model',ElasticNet())])

grid = GridSearchCV(pipeline, cv=5, param_grid=params,scoring='neg_mean_squared_error')
grid.fit(X_train, y_train)
grid.best_params_
# Out:
# C:\Users\Abhinav\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 383257528104.6338, tolerance: 474197.79504692584
#   positive)
# C:\Users\Abhinav\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 252981193882.5513, tolerance: 483985.51269522466
#   positive)
# C:\Users\Abhinav\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 426555390250.00946, tolerance: 484203.806080445
#   positive)
# ...

# %%
# %%time
params={'model__random_state':[42],
        'model__alpha':[.01,.1,1,15,25,35,100],
        'model__max_iter':[15,50,100,125,150],
       'model__tol':[1e-07,1e-05,1e-03,.1],
       'model__solver':('auto','lsqr', 'sag', 'saga')}


pipeline = Pipeline([('scaler', RobustScaler()),('model',Ridge())])

grid = GridSearchCV(pipeline, cv=5, param_grid=params,scoring='neg_mean_squared_error')
grid.fit(X_train, y_train)
grid.best_params_
# Out:
# C:\Users\Abhinav\anaconda3\lib\site-packages\sklearn\linear_model\_sag.py:330: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)
# C:\Users\Abhinav\anaconda3\lib\site-packages\sklearn\linear_model\_sag.py:330: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)
# C:\Users\Abhinav\anaconda3\lib\site-packages\sklearn\linear_model\_sag.py:330: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)
# C:\Users\Abhinav\anaconda3\lib\site-packages\sklearn\linear_model\_sag.py:330: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)
# ...

# %%
# %%time
params={'model__C':[1,3,5,10,15],
       'model__gamma':[1e-05,.001,.01,],
       'model__epsilon':[.001,.01,.1],
       'model__tol':[1e-07,1e-05,.001],
       'model__kernel':['rbf']}


pipeline = Pipeline([('scaler', RobustScaler()),('model',SVR())])

grid = GridSearchCV(pipeline, cv=5, param_grid=params,scoring='neg_mean_squared_error')
grid.fit(X_train, y_train)
grid.best_params_
# Out:
# Wall time: 5min 10s
# {'model__C': 15,
#  'model__epsilon': 0.1,
#  'model__gamma': 0.01,
#  'model__kernel': 'rbf',
#  'model__tol': 1e-07}

# %%
kf = KFold(5, shuffle=True, random_state=42)
def rmsecv(model):
    rmse= np.sqrt(-cross_val_score(model, X_train, y_train, cv = kf,scoring='neg_mean_squared_error',error_score='raise'))
    scores.append(['{:3f}'.format(rmse.mean()),'{:3f}'.format(rmse.std())])

# %%
lasso=make_pipeline(RobustScaler(),Lasso(alpha= 0.005,
                                         max_iter= 14,
                                         normalize= True,
                                         positive= True,
                                         random_state= 42,
                                         selection= 'random',
                                         tol= 1e-06,
                                         warm_start= True))
elasticnet=make_pipeline(RobustScaler(),ElasticNet(alpha= 0.0095,
                                                   l1_ratio= 0.55,
                                                   max_iter= 120,
                                                   normalize=False,
                                                   positive=True,
                                                   random_state= 42,
                                                   selection= 'random',
                                                   tol= 1e-07))
ridge=make_pipeline(RobustScaler(),Ridge(random_state=42,
                                         alpha=35,
                                          solver='lsqr',
                                          tol=1e-07,
                                          max_iter=50))
svr=make_pipeline(RobustScaler(),SVR(C= 15,
                                    epsilon= 0.1,
                                    gamma= 0.01,
                                    kernel= 'rbf',
                                    tol= 1e-07))

# %%
models=[
        lasso,
        elasticnet,
        ridge,
        svr,
        DecisionTreeRegressor(random_state=42,
                              criterion= 'friedman_mse',
                              max_depth= 13,
                              min_samples_leaf= 5,
                              min_samples_split= 15,
                              splitter= 'best'),

        RandomForestRegressor(random_state=42,
                              max_depth=15,
                              min_samples_split=2,
                              min_samples_leaf=1,
                              n_estimators=500
                                ),

        GradientBoostingRegressor(n_estimators=3870,
                                  learning_rate=0.008,
                                  max_depth=3,
                                  max_features='sqrt',
                                  criterion='friedman_mse',
                                  min_samples_leaf=15,
                                  min_samples_split=10,
                                  loss='huber',random_state=42) ,
  
        xgb(random_state=42,verbosity=0,
            n_estimators=6000,
            learning_rate=0.01, 
            colsample_bytree=0.66, 
            gamma=0.0258, 
            max_depth=3, 
            min_child_weight=1.081, 
            reg_alpha=0.4640, 
            reg_lambda=1.9071,
            subsample=0.5213 ,
            silent=1,
            nthread = -1,)
       ]

# %%
# %%time
scores=[]
for i in models:
    try:
        rmsecv(i)
    except Exception as e:
        print(i,'\n',e)
# Out:
# C:\Users\Abhinav\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 304331687732.35223, tolerance: 4873581.410150979
#   positive)
# C:\Users\Abhinav\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 328667163199.74304, tolerance: 5370970.647565516
#   positive)
# C:\Users\Abhinav\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 258755702144.5663, tolerance: 4953681.852665752
#   positive)
# ...

# %%
mods=['Lasso','ElasticNet','Ridge','SVR','DecisionTree','RandomForest','GradientBoosting','XGBoost']
scores
df=(pd.DataFrame(scores,index=mods,columns=['RMSE','STD']))
df['RMSE'] = df['RMSE'].astype(float, errors = 'raise')

# %%
fig,axes=plt.subplots(1,1,figsize=(15,9))
fig.patch.set_facecolor('#000000')
axes.patch.set_facecolor('#000000')
axes.tick_params(axis='x', colors='white')
axes.tick_params(axis='y', colors='white')
axes.yaxis.set_ticks_position('none')
axes.yaxis.label.set_color('White')
axes.axvline(df['RMSE'].mean(), ls='--',color='#909090')
axes.text(df['RMSE'].mean()+.001,8, "Average={:.5f}".format(df['RMSE'].mean()),color='white',size=12,fontweight='bold')
axes.text(df['RMSE'].max()-.015,-1,'Lower is Better',color='grey',size=12,fontweight='bold')
# axes.grid(False)
axes.yaxis.label.set_fontsize(5)
plt.xticks(fontsize=13)
plt.yticks(fontsize=13)
sns.barplot(x=df['RMSE'],y=df.index,palette='viridis')
for p in axes.patches:
            value = '{:.5f}'.format(p.get_width())
            x = p.get_x() + p.get_width()-.015
            y = p.get_y() + p.get_height()-.3
            axes.text(x, y, (value), ha="left",fontsize=13,color='#ffffff',bbox=dict(facecolor='#000000', edgecolor='white',boxstyle='round', linewidth=1.25))
plt.title('RMSE',size=25,color=('#ffffff'),fontweight=('bold'),y=1.03);

# %%
grad_boost = GradientBoostingRegressor(n_estimators=3870,
                                  learning_rate=0.008,
                                  max_depth=3,
                                  max_features='sqrt',
                                  criterion='friedman_mse',
                                  min_samples_leaf=15,
                                  min_samples_split=10,
                                  loss='huber',random_state=42)

# %%
grad_boost.fit(X_train,y_train)
# Out:
# GradientBoostingRegressor(alpha=0.9, ccp_alpha=0.0, criterion='friedman_mse',
#                           init=None, learning_rate=0.008, loss='huber',
#                           max_depth=3, max_features='sqrt', max_leaf_nodes=None,
#                           min_impurity_decrease=0.0, min_impurity_split=None,
#                           min_samples_leaf=15, min_samples_split=10,
#                           min_weight_fraction_leaf=0.0, n_estimators=3870,
#                           n_iter_no_change=None, presort='deprecated',
#                           random_state=42, subsample=1.0, tol=0.0001,
#                           validation_fraction=0.1, verbose=0, warm_start=False)

# %%
pred_grad = grad_boost.predict(X_test)

# %%
plt.figure(figsize=(15,9))
sns.scatterplot(y=y_test,x=pred_grad)
plt.ylabel('True')
plt.xlabel('Predicted');

# %%
pred_grad1 = grad_boost.predict(test_df)

# %%
pred_grad2 = pd.DataFrame(pred_grad1)
sub_df=pd.read_csv('sample_submission.csv')
datasets=pd.concat([sub_df['Id'],pred_grad2],axis=1)
datasets.columns=['Id','SalePrice']
datasets.to_csv('sample_submission.csv',index=False)

# %%
from sklearn.model_selection import train_test_split
X = train_df.drop(['SalePrice'],axis=1)
y = train_df['SalePrice']

# %%
from sklearn.linear_model import LinearRegression

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size = 0.3,random_state = 42)

# %%
lm = LinearRegression()

# %%
lm.fit(X_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
pred = lm.predict(X_test)

# %%
from sklearn import metrics

# %%
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, pred)))
# Out:
# RMSE: 43850.05181558452

# %%
pred1 = lm.predict(test_df)

# %%
pred2=pd.DataFrame(pred1)
sub_df=pd.read_csv('sample_submission.csv')
datasets=pd.concat([sub_df['Id'],pred2],axis=1)
datasets.columns=['Id','SalePrice']
datasets.to_csv('sample_submission.csv',index=False)

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaler.fit(X_train)

X_train_std = pd.DataFrame(scaler.transform(X_train), columns=X_train.columns, index=X_train.index)
X_test_std = pd.DataFrame(scaler.transform(X_test), columns=X_test.columns, index=X_test.index)

# %%
X_train_std.describe()
# Out:
#          MSSubClass   LotFrontage       LotArea   OverallQual   OverallCond  \
# count  1.022000e+03  1.022000e+03  1.022000e+03  1.022000e+03  1.022000e+03
# mean   2.991736e-16 -2.021649e-16  9.277206e-17 -4.323569e-17 -3.476236e-17
# std    1.000490e+00  1.000490e+00  1.000490e+00  1.000490e+00  1.000490e+00
# min   -8.689496e-01 -2.141813e+00 -8.340925e-01 -3.741231e+00 -4.112182e+00
# 25%   -8.689496e-01 -4.479787e-01 -2.809192e-01 -8.230565e-01 -5.086236e-01
# 50%   -1.655306e-01 -1.149258e-02 -1.011494e-01 -9.351293e-02 -5.086236e-01
# 75%    3.034154e-01  3.772224e-01  8.363168e-02  6.360307e-01  3.922660e-01
# max    3.117091e+00  1.054023e+01  1.805862e+01  2.824662e+00  3.094935e+00
#
#           YearBuilt  YearRemodAdd    MasVnrArea    BsmtFinSF1    BsmtFinSF2  \
# count  1.022000e+03  1.022000e+03  1.022000e+03  1.022000e+03  1.022000e+03
# mean  -2.276935e-15  5.069005e-15  1.436392e-16  2.085742e-17  1.037439e-16
# ...

# %%
from sklearn.tree import DecisionTreeRegressor
 
# create a regressor object
regressor = DecisionTreeRegressor(random_state = 0)
 
# fit the regressor with X and Y data
regressor.fit(X_train, y_train)
# Out:
# DecisionTreeRegressor(ccp_alpha=0.0, criterion='mse', max_depth=None,
#                       max_features=None, max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, presort='deprecated',
#                       random_state=0, splitter='best')

# %%
pred_tree = regressor.predict(test_df)

# %%
pred_tree
# Out:
# array([120500., 168500., 208900., ..., 145000., 147000., 250000.])

# %%
pred_tree.shape
# Out:
# (1459,)

# %%
pred_tree1=pd.DataFrame(pred_tree)
sub_df=pd.read_csv('sample_submission.csv')
datasets=pd.concat([sub_df['Id'],pred_tree1],axis=1)
datasets.columns=['Id','SalePrice']
datasets.to_csv('sample_submission.csv',index=False)

# %%
from sklearn.model_selection import GridSearchCV

# %%
params = {
    'max_depth': [2, 3, 5, 10, 20],
    'min_samples_leaf': [5, 10, 20, 50, 100],
    'criterion': ["mse", "friedman_mse", "mae"]
}

# %%
score = np.sqrt(metrics.mean_squared_error(y_test, pred))

# %%
grid_search = GridSearchCV(estimator=regressor, 
                           param_grid=params, 
                           cv=4, n_jobs=-1, verbose=1)

# %%
grid_search.fit(X_train, y_train)
# Out:
# Fitting 4 folds for each of 75 candidates, totalling 300 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  48 tasks      | elapsed:    5.4s
# [Parallel(n_jobs=-1)]: Done 300 out of 300 | elapsed:   15.2s finished
# GridSearchCV(cv=4, error_score=nan,
#              estimator=DecisionTreeRegressor(ccp_alpha=0.0, criterion='mse',
#                                              max_depth=None, max_features=None,
#                                              max_leaf_nodes=None,
#                                              min_impurity_decrease=0.0,
#                                              min_impurity_split=None,
#                                              min_samples_leaf=1,
#                                              min_samples_split=2,
#                                              min_weight_fraction_leaf=0.0,
#                                              presort='deprecated',
# ...

# %%
grid_search.best_params_
# Out:
# {'criterion': 'mse', 'max_depth': 10, 'min_samples_leaf': 10}

# %%
grid_search.best_estimator_
# Out:
# DecisionTreeRegressor(ccp_alpha=0.0, criterion='mse', max_depth=10,
#                       max_features=None, max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=10, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, presort='deprecated',
#                       random_state=0, splitter='best')

# %%
pred_tune = grid_search.predict(test_df)

# %%
pred_tune1=pd.DataFrame(pred_tune)
sub_df=pd.read_csv('sample_submission.csv')
datasets=pd.concat([sub_df['Id'],pred_tune1],axis=1)
datasets.columns=['Id','SalePrice']
datasets.to_csv('sample_submission.csv',index=False)

# %%
pred = grid_search.predict(X_test)

# %%
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, pred)))
# Out:
# RMSE: 42247.00301116999

# %%
from sklearn.svm import SVR

# %%
svr = SVR(kernel = 'rbf')

# %%
svr.fit(X_train,y_train)
# Out:
# SVR(C=1.0, cache_size=200, coef0=0.0, degree=3, epsilon=0.1, gamma='scale',
#     kernel='rbf', max_iter=-1, shrinking=True, tol=0.001, verbose=False)

# %%
pred_svr = svr.predict(test_df)

# %%
pred_svr1 = svr.predict(X_test)

# %%
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, pred_svr1)))
# Out:
# RMSE: 84860.09522200038

# %%
pred_sv=pd.DataFrame(pred_svr)
sub_df=pd.read_csv('sample_submission.csv')
datasets=pd.concat([sub_df['Id'],pred_sv],axis=1)
datasets.columns=['Id','SalePrice']
datasets.to_csv('sample_submission.csv',index=False)

# %%
svr = SVR(kernel = 'rbf' ,C = 1,gamma = 1)

# %%
svr.fit(X_train,y_train)
# Out:
# SVR(C=1, cache_size=200, coef0=0.0, degree=3, epsilon=0.1, gamma=1,
#     kernel='rbf', max_iter=-1, shrinking=True, tol=0.001, verbose=False)

# %%
pred_sv1 = svr.predict(test_df)

# %%
pred_sv2 = svr.predict(X_test)

# %%
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, pred_sv2)))
# Out:
# RMSE: 84872.45643236427

# %%
pred_sv3=pd.DataFrame(pred_sv1)
sub_df=pd.read_csv('sample_submission.csv')
datasets=pd.concat([sub_df['Id'],pred_sv3],axis=1)
datasets.columns=['Id','SalePrice']
datasets.to_csv('sample_submission.csv',index=False)

# %%
import keras
from keras import regularizers, optimizers
from keras.layers import Dense
from keras.models import Sequential
from keras.callbacks import EarlyStopping, ReduceLROnPlateau



## Just a way to define neural nets. There are two ways sequential and functional
## Sequential model lets you add neural net layers one after another by calling function
model = Sequential()



model.add(Dense(1,input_shape=(8,), activation='sigmoid', kernel_regularizer=regularizers.l2()))

# %%
import tensorflow as tf

# %%
def my_loss_fn(y_true, y_pred):
    squared_difference = tf.square(y_true - y_pred)
    return tf.reduce_mean(squared_difference, axis=-1)  # Note the `axis=-1`

model.compile(optimizer='adam', loss=my_loss_fn)

# %%
# Importing the Keras libraries and packages
import keras
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LeakyReLU,PReLU,ELU
from keras.layers import Dropout


# Initialising the ANN
regress = Sequential()

# Adding the input layer and the first hidden layer
regress.add(Dense(50,activation='relu',input_dim = 176))

# Adding the second hidden layer
regress.add(Dense(25,activation='relu'))

# Adding the third hidden layer
regress.add(Dense(50,activation='relu'))
# Adding the output layer
regress.add(Dense(1))

# Compiling the ANN
regress.compile(loss= my_rmse, optimizer='Adamax', metrics=[tf.keras.metrics.RootMeanSquaredError()])

# Fitting the ANN to the Training set
model_history=regress.fit(X_train.values, y_train.values,validation_split=0.20, batch_size = 10, epochs = 1000)
# Out:
# Epoch 1/1000
# 82/82 [==============================] - 1s 6ms/step - loss: 191496.6875 - root_mean_squared_error: 194111.3594 - val_loss: 185863.0781 - val_root_mean_squared_error: 187560.2812
# Epoch 2/1000
# 82/82 [==============================] - 0s 3ms/step - loss: 173397.3438 - root_mean_squared_error: 176609.2812 - val_loss: 153542.2188 - val_root_mean_squared_error: 155263.7812
# Epoch 3/1000
# 82/82 [==============================] - 0s 3ms/step - loss: 112669.2500 - root_mean_squared_error: 122052.3906 - val_loss: 71846.3828 - val_root_mean_squared_error: 74443.8516
# Epoch 4/1000
# 82/82 [==============================] - 0s 3ms/step - loss: 73451.8359 - root_mean_squared_error: 89724.8594 - val_loss: 56891.4102 - val_root_mean_squared_error: 60355.3906
# Epoch 5/1000
# 82/82 [==============================] - 0s 3ms/step - loss: 68120.5156 - root_mean_squared_error: 88632.3984 - val_loss: 55690.0859 - val_root_mean_squared_error: 58999.7773
# Epoch 6/1000
# ...

# %%
ann_pred = regress.predict(test_df)

# %%
ann_pred1=pd.DataFrame(ann_pred)
sub_df=pd.read_csv('sample_submission.csv')
datasets=pd.concat([sub_df['Id'],ann_pred1],axis=1)
datasets.columns=['Id','SalePrice']
datasets.to_csv('sample_submission.csv',index=False)

# %%
def my_rmse(y_true, y_pred):
    error = y_true - y_pred
    sqr_error = tf.square(error)
    mean_sqr_error = tf.math.reduce_mean(sqr_error)
    sqrt_mean_sqr_error = tf.math.sqrt(mean_sqr_error)
    return sqrt_mean_sqr_error

# %%
import xgboost
regressor=xgboost.XGBRegressor()

# %%
booster=['gbtree','gblinear']
base_score=[0.25,0.5,0.75,1]

# %%
## Hyper Parameter Optimization


n_estimators = [100, 500, 900, 1100, 1500]
max_depth = [2, 3, 5, 10, 15]
booster=['gbtree','gblinear']
learning_rate=[0.05,0.1,0.15,0.20]
min_child_weight=[1,2,3,4]

# Define the grid of hyperparameters to search
hyperparameter_grid = {
    'n_estimators': n_estimators,
    'max_depth':max_depth,
    'learning_rate':learning_rate,
    'min_child_weight':min_child_weight,
    'booster':booster,
    'base_score':base_score
    }

# %%
from sklearn.model_selection import RandomizedSearchCV

# %%
# Set up the random search with 4-fold cross validation
random_cv = RandomizedSearchCV(estimator=regressor,
            param_distributions=hyperparameter_grid,
            cv=5, n_iter=50,
            scoring = 'neg_mean_absolute_error',n_jobs = 4,
            verbose = 5, 
            return_train_score = True,
            random_state=42)

# %%
random_cv.fit(X_train,y_train)
# Out:
# Fitting 5 folds for each of 50 candidates, totalling 250 fits
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  10 tasks      | elapsed:   35.4s
# [Parallel(n_jobs=4)]: Done  64 tasks      | elapsed:  5.6min
# [Parallel(n_jobs=4)]: Done 154 tasks      | elapsed: 11.2min
# [Parallel(n_jobs=4)]: Done 250 out of 250 | elapsed: 16.7min finished
# [23:47:08] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# RandomizedSearchCV(cv=5, error_score=nan,
#                    estimator=XGBRegressor(base_score=0.5, booster='gbtree',
#                                           colsample_bylevel=1,
#                                           colsample_bynode=1,
#                                           colsample_bytree=1, gamma=0,
#                                           importance_type='gain',
#                                           learning_rate=0.1, max_delta_step=0,
# ...

# %%
random_cv.best_estimator_
# Out:
# XGBRegressor(base_score=0.25, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=1, gamma=0,
#              importance_type='gain', learning_rate=0.1, max_delta_step=0,
#              max_depth=2, min_child_weight=1, missing=None, n_estimators=900,
#              n_jobs=1, nthread=None, objective='reg:linear', random_state=0,
#              reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=None,
#              silent=None, subsample=1, verbosity=1)

# %%
regressor=xgboost.XGBRegressor(base_score=0.25, booster='gbtree', colsample_bylevel=1,
       colsample_bytree=1, gamma=0, learning_rate=0.1, max_delta_step=0,
       max_depth=2, min_child_weight=1, missing=None, n_estimators=900,
       n_jobs=1, nthread=None, objective='reg:linear', random_state=0,
       reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=None,
       silent=True, subsample=1)

# %%
regressor.fit(X_train,y_train)
# Out:
# XGBRegressor(base_score=0.25, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=1, gamma=0,
#              importance_type='gain', learning_rate=0.1, max_delta_step=0,
#              max_depth=2, min_child_weight=1, missing=None, n_estimators=900,
#              n_jobs=1, nthread=None, objective='reg:linear', random_state=0,
#              reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=None,
#              silent=True, subsample=1, verbosity=1)

# %%
pred_xg = regressor.predict(test_df)

# %%
pred_xg1=pd.DataFrame(pred_xg)
sub_df=pd.read_csv('sample_submission.csv')
datasets=pd.concat([sub_df['Id'],pred_xg1],axis=1)
datasets.columns=['Id','SalePrice']
datasets.to_csv('sample_submission.csv',index=False)
